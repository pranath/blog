# %% [markdown]
# # State-of-the-art deep learning image model techniques in 2021
# > In this article I look at
#
# - toc: true
# - comments: true
# - image: images/deep2.jpg
# - categories: [deep-learning-theory]
